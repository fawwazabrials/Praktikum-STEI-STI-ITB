# %%
# NIM/Nama  : 16521115/Fawwaz Abrial Saffa
# Tanggal   : 29 November 2021

# %%
import pandas as pd
data = pd.read_csv('H05.csv')

# %%
# 1. Histogram distribusi nilai matematika
data['nilai_mat'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# 2. Diagram batang horizontal banyaknya mahasiswa masing-masing fakultas
data['fakultas'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# 3. Diagram pie banyaknya mahasiswa masing-masing fakultas
data['fakultas'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='fakultas'>

# %% [markdown]
# 4. Berdasarkan diagram pie dan batang horizontal, manakah fakultas dengan mahasiswa terbanyak? Manakah diagram yang lebih baik dalam menampilkan fakultas dengan mahasiswa terbanyak dan mengapa?
#
# JAWAB:
# Dari diagram, terlihat kalau fakultas FTI memiliki mahasiswa terbanyak. Menurut saya pribadi pie chart, selama masih ada alternatif diagram lain, adalah diagram yang paling buruk untuk digunakan. Ambiguitas dalam melihat sudut tiap kategori merupakan hal yang membuat pie chart diagram yang paling buruk. Oleh karena itu dalam kasus ini diagram batang horizontal merupakan diagram yang cocok untuk menambilkan fakultas dengan mahasiswa terbanyak karena bisa dilihat ketinggiannya dengan jelas.

# %%
# 5. Scatter plot dengan nilai kimia sebagai x dan fisika sebagai y
data.plot(kind='scatter', x='nilai_kim', y='nilai_fis')
# Out:
# <AxesSubplot:xlabel='nilai_kim', ylabel='nilai_fis'>
